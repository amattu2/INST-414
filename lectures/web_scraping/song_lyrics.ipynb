# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.azlyrics.com/lyrics/philcollins/anotherdayinparadise.html"

page = requests.get(url)
page.status_code
# Out:
# 200

# %%
soup = bs(page.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Phil Collins &quot;Another Day In Paradise&quot;: She calls out to the man on the street &quot;Sir, can you help me? It's cold and I've nowhere to sleep Is..." name="description"/>
#   <meta content="Another Day In Paradise lyrics, Phil Collins Another Day In Paradise lyrics, Phil Collins lyrics" name="keywords"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content="//www.azlyrics.com/az_logo_tr.png" property="og:image"/>
#   <title>
#    Phil Collins - Another Day In Paradise Lyrics | AZLyrics.com
#   </title>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/local/az.css" rel="stylesheet"/>
# ...

# %%
main_body = soup.find_all(class_= "col-xs-12 col-lg-8 text-center")

# %%
main_body
# Out:
# [<div class="col-xs-12 col-lg-8 text-center">
#  <div class="div-share noprint">
#  <div class="addthis_toolbox addthis_default_style">
#  <a class="btn btn-xs btn-share addthis_button_facebook" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.azlyrics.com%2Flyrics%2Fphilcollins%2Fanotherdayinparadise.html&amp;title=Phil%20Collins%20-%20Another%20Day%20In%20Paradise%20Lyrics%20%7C%20AZLyrics.com&amp;display=page" target="_blank">
#  <span class="playblk"><img alt="Share on Facebook" class="playblk" height="25" src="//www.azlyrics.com/images/share-icons/facebook.svg" title="Share on Facebook" width="25"/></span>
#  </a>
#  <a class="btn btn-xs btn-share addthis_button_twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.azlyrics.com%2Flyrics%2Fphilcollins%2Fanotherdayinparadise.html&amp;text=Phil%20Collins%20-%20Another%20Day%20In%20Paradise%20Lyrics%20%7C%20AZLyrics.com" target="_blank">
# ...
